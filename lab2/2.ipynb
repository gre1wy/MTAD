# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
import seaborn as sns
print("Setup completed")
# Out:
# Setup completed

# %%
df = pd.read_csv('C:/Users/igorv/PythonProj/MTIAD/1-7/cost-of-living.csv')
df = df.drop(columns = 'Unnamed: 0', axis = 1)
df
# Out:
#                     city      country     x1     x2     x3     x4    x5    x6  \
# 0                  Delhi        India   4.90  22.04   4.28   1.84  3.67  1.78
# 1               Shanghai        China   5.59  40.51   5.59   1.12  4.19  3.96
# 2                Jakarta    Indonesia   2.54  22.25   3.50   2.02  3.18  2.19
# 3                 Manila  Philippines   3.54  27.40   3.54   1.24  1.90  2.91
# 4                  Seoul  South Korea   7.16  52.77   6.03   3.02  4.52  3.86
# ...                  ...          ...    ...    ...    ...    ...   ...   ...
# 4869        Peterborough    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4870          Georgetown    Australia    NaN    NaN    NaN    NaN   NaN   NaN
# 4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99   NaN  1.82
# 4872             Iqaluit       Canada  29.78  74.61  13.77   6.70  8.93  3.72
# 4873              Neiafu        Tonga    NaN  29.53  10.55  10.55   NaN   NaN
#
# ...

# %%
df_clear = df.dropna()
df_clear.index = np.arange(1, len(df_clear) + 1)
df_clear
# Out:
#                      city        country     x1     x2     x3    x4    x5  \
# 1                   Delhi          India   4.90  22.04   4.28  1.84  3.67
# 2                Shanghai          China   5.59  40.51   5.59  1.12  4.19
# 3                 Jakarta      Indonesia   2.54  22.25   3.50  2.02  3.18
# 4                  Manila    Philippines   3.54  27.40   3.54  1.24  1.90
# 5                   Seoul    South Korea   7.16  52.77   6.03  3.02  4.52
# ...                   ...            ...    ...    ...    ...   ...   ...
# 1260    Erlenbach am Main        Germany  15.58  51.93   8.31  4.15  4.15
# 1261           Gig Harbor  United States  12.00  40.00  10.50  7.00  6.00
# 1262  Murovani Kurylivtsi        Ukraine   2.71  12.17   2.68  0.67  1.08
# 1263             Tirupati          India   2.45   9.18   4.28  2.11  3.06
# 1264         Egilsstadhir        Iceland  17.30  70.61   8.47  4.24  3.53
#
#         x6    x7    x8  ...     x47      x48      x49      x50      x51  \
# ...

# %%
df_clear = df_clear.drop(df_clear.columns[[5,6,8]], axis = 1)
df_clear
# Out:
#                      city        country     x1     x2     x3    x6    x8  \
# 1                   Delhi          India   4.90  22.04   4.28  1.78  0.19
# 2                Shanghai          China   5.59  40.51   5.59  3.96  0.32
# 3                 Jakarta      Indonesia   2.54  22.25   3.50  2.19  0.27
# 4                  Manila    Philippines   3.54  27.40   3.54  2.91  0.51
# 5                   Seoul    South Korea   7.16  52.77   6.03  3.86  0.78
# ...                   ...            ...    ...    ...    ...   ...   ...
# 1260    Erlenbach am Main        Germany  15.58  51.93   8.31  3.40  2.35
# 1261           Gig Harbor  United States  12.00  40.00  10.50  5.15  1.92
# 1262  Murovani Kurylivtsi        Ukraine   2.71  12.17   2.68  0.68  0.13
# 1263             Tirupati          India   2.45   9.18   4.28  2.01  0.13
# 1264         Egilsstadhir        Iceland  17.30  70.61   8.47  3.95  1.41
#
#         x9   x10   x11  ...     x47      x48      x49      x50      x51  \
# ...

# %%
df_clear = df_clear.drop(df.iloc[:,25:55], axis=1)
df_clear
# Out:
#                      city        country     x1     x2     x3    x6    x8  \
# 1                   Delhi          India   4.90  22.04   4.28  1.78  0.19
# 2                Shanghai          China   5.59  40.51   5.59  3.96  0.32
# 3                 Jakarta      Indonesia   2.54  22.25   3.50  2.19  0.27
# 4                  Manila    Philippines   3.54  27.40   3.54  2.91  0.51
# 5                   Seoul    South Korea   7.16  52.77   6.03  3.86  0.78
# ...                   ...            ...    ...    ...    ...   ...   ...
# 1260    Erlenbach am Main        Germany  15.58  51.93   8.31  3.40  2.35
# 1261           Gig Harbor  United States  12.00  40.00  10.50  5.15  1.92
# 1262  Murovani Kurylivtsi        Ukraine   2.71  12.17   2.68  0.68  0.13
# 1263             Tirupati          India   2.45   9.18   4.28  2.01  0.13
# 1264         Egilsstadhir        Iceland  17.30  70.61   8.47  3.95  1.41
#
#         x9   x10   x11  ...   x17   x18   x19   x20   x21   x22   x23  \
# ...

# %%
df_clear = df_clear.drop(columns = {'x54','x55','data_quality'})
df_clear
# Out:
#                      city        country     x1     x2     x3    x6    x8  \
# 1                   Delhi          India   4.90  22.04   4.28  1.78  0.19
# 2                Shanghai          China   5.59  40.51   5.59  3.96  0.32
# 3                 Jakarta      Indonesia   2.54  22.25   3.50  2.19  0.27
# 4                  Manila    Philippines   3.54  27.40   3.54  2.91  0.51
# 5                   Seoul    South Korea   7.16  52.77   6.03  3.86  0.78
# ...                   ...            ...    ...    ...    ...   ...   ...
# 1260    Erlenbach am Main        Germany  15.58  51.93   8.31  3.40  2.35
# 1261           Gig Harbor  United States  12.00  40.00  10.50  5.15  1.92
# 1262  Murovani Kurylivtsi        Ukraine   2.71  12.17   2.68  0.68  0.13
# 1263             Tirupati          India   2.45   9.18   4.28  2.01  0.13
# 1264         Egilsstadhir        Iceland  17.30  70.61   8.47  3.95  1.41
#
#         x9   x10   x11  ...    x14    x15   x16   x17   x18   x19   x20   x21  \
# ...

# %%
df_clear.to_csv(r'dataset_clear.csv', sep = ',')

# %%
df_clear.mean()
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_8104\392622123.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clear.mean()
# x1      9.781661
# x2     43.969059
# x3      6.808790
# x6      2.639106
# x8      1.088829
# x9      1.164660
# x10     1.512389
# x11     1.923987
# x12     2.313141
# x13     9.472967
# x14     6.948149
# x15    11.928291
# x16     2.413813
# x17     1.520435
# x18     2.075388
# x19     2.281400
# x20     1.371076
# x21     1.322366
# x22     1.153172
# x23     0.886938
# dtype: float64

# %%
df_stats = df_clear.drop(columns={'city','country'})

# %%
sc.stats.trim_mean(df_stats,0.1).reshape(-1,1)
# Out:
# array([[ 9.38216403],
#        [42.2702668 ],
#        [ 6.66719368],
#        [ 2.55867589],
#        [ 1.01443676],
#        [ 1.1018083 ],
#        [ 1.40268775],
#        [ 1.70836957],
#        [ 2.22536561],
#        [ 9.00465415],
#        [ 6.49568182],
#        [10.9851087 ],
#        [ 2.22427866],
#        [ 1.45636364],
#        [ 1.88701581],
#        [ 2.10779644],
#        [ 1.2343083 ],
#        [ 1.2012253 ],
#        [ 1.07755929],
#        [ 0.80287549]])

# %%
print(df_clear.median())
# Out:
# x1      8.990
# x2     40.000
# x3      6.550
# x6      2.515
# x8      0.970
# x9      1.070
# x10     1.260
# x11     1.585
# x12     2.130
# x13     8.540
# x14     6.165
# x15    10.380
# x16     2.100
# x17     1.435
# x18     1.740
# x19     1.930
# x20     1.115
# x21     1.090
# x22     1.000
# x23     0.690
# dtype: float64
# C:\Users\igorv\AppData\Local\Temp\ipykernel_8104\761294603.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df_clear.median())

# %%
df_clear.var()
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_8104\2504833514.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clear.var()
# x1      37.477771
# x2     618.725689
# x3       6.773171
# x6       1.497352
# x8       0.569485
# x9       0.244394
# x10      0.904798
# x11      1.632675
# x12      1.006633
# x13     20.862828
# x14     14.126407
# x15     50.460438
# x16      2.348633
# x17      0.550961
# x18      1.715810
# x19      2.246575
# x20      1.013137
# x21      0.817639
# x22      0.470176
# x23      0.328153
# dtype: float64

# %%
df_clear.std()
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_8104\3593009202.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_clear.std()
# x1      6.121909
# x2     24.874197
# x3      2.602532
# x6      1.223663
# x8      0.754642
# x9      0.494362
# x10     0.951209
# x11     1.277762
# x12     1.003311
# x13     4.567584
# x14     3.758511
# x15     7.103551
# x16     1.532525
# x17     0.742268
# x18     1.309889
# x19     1.498858
# x20     1.006547
# x21     0.904234
# x22     0.685694
# x23     0.572847
# dtype: float64

# %%
df_clear.mad()
# Out:
# C:\Users\igorv\AppData\Local\Temp\ipykernel_8104\1658393414.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df_clear.mad()
# x1      5.225026
# x2     20.734387
# x3      2.067450
# x6      1.035420
# x8      0.615366
# x9      0.334379
# x10     0.754709
# x11     0.897107
# x12     0.786231
# x13     3.457439
# x14     2.878156
# x15     4.746497
# x16     1.041314
# x17     0.456014
# x18     0.956002
# x19     1.157329
# x20     0.698434
# x21     0.656986
# x22     0.503914
# x23     0.446571
# dtype: float64

# %%
print(sc.stats.median_abs_deviation(df_stats).reshape(-1,1))
# Out:
# [[ 5.13 ]
#  [19.73 ]
#  [ 1.76 ]
#  [ 0.935]
#  [ 0.555]
#  [ 0.23 ]
#  [ 0.595]
#  [ 0.575]
#  [ 0.61 ]
#  [ 2.68 ]
#  [ 2.285]
#  [ 3.23 ]
#  [ 0.73 ]
#  [ 0.325]
#  [ 0.64 ]
#  [ 0.87 ]
#  [ 0.495]
#  [ 0.44 ]
#  [ 0.365]
#  [ 0.27 ]]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_min_max = pd.DataFrame(scaler.fit_transform(df_stats))
df_min_max.to_csv(r'dataset_min_max_normalized.csv', sep = ',', index = False)
df_min_max
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.136320  0.113728  0.138923  0.190934  0.024943  0.052960  0.063516
# 1     0.158556  0.241654  0.219094  0.490385  0.054422  0.356698  0.367799
# 2     0.060264  0.115182  0.091187  0.247253  0.043084  0.138629  0.166913
# 3     0.092491  0.150852  0.093635  0.346154  0.097506  0.193146  0.163959
# 4     0.209152  0.326569  0.246022  0.476648  0.158730  0.271028  0.398818
# ...        ...       ...       ...       ...       ...       ...       ...
# 1259  0.480503  0.320751  0.385557  0.413462  0.514739  0.110592  0.525849
# 1260  0.365131  0.238122  0.519584  0.653846  0.417234  0.155763  0.608567
# 1261  0.065743  0.045366  0.041004  0.039835  0.011338  0.054517  0.069424
# 1262  0.057364  0.024657  0.138923  0.222527  0.011338  0.029595  0.072378
# 1263  0.535933  0.450132  0.395349  0.489011  0.301587  0.104361  0.409158
#
# ...

# %%
from sklearn import preprocessing
d = preprocessing.normalize(df_stats)
scaled_df = pd.DataFrame(d)
scaled_df.to_csv(r'dataset_mean_normalization.csv', sep = ',', index = False)

# %%
df_clear.head()
# Out:
#        city      country    x1     x2    x3    x6    x8    x9   x10   x11  \
# 1     Delhi        India  4.90  22.04  4.28  1.78  0.19  0.73  0.51  0.88
# 2  Shanghai        China  5.59  40.51  5.59  3.96  0.32  2.68  2.57  1.18
# 3   Jakarta    Indonesia  2.54  22.25  3.50  2.19  0.27  1.28  1.21  0.83
# 4    Manila  Philippines  3.54  27.40  3.54  2.91  0.51  1.63  1.19  0.89
# 5     Seoul  South Korea  7.16  52.77  6.03  3.86  0.78  2.13  2.78  3.66
#
#    ...    x14    x15   x16   x17   x18   x19   x20   x21   x22   x23
# 1  ...   3.79   5.57  1.80  0.75  1.01  0.60  0.36  0.41  0.70  0.36
# 2  ...   4.67  12.79  2.22  1.55  2.11  1.47  0.82  1.02  0.82  0.62
# 3  ...   3.46   8.32  2.80  1.52  2.08  1.24  1.35  2.10  1.13  0.42
# 4  ...   4.19   6.64  2.66  1.42  2.95  1.42  1.76  1.75  1.36  0.65
# 5  ...  10.62  40.41  6.79  3.70  6.40  6.36  3.86  2.81  2.40  1.06
#
# [5 rows x 22 columns]

# %%
df_clear = df_clear

# %%
sns.histplot(x=df_clear['x3']).set(xlabel = 'McDonalds')
# Out:
# [Text(0.5, 0, 'McDonalds')]

# %%
sns.displot(x = df_clear['x3'], color = 'b', bw_adjust = 2, kind = 'kde')

# %%
df_clear = df_clear[:5]

# %%
sns.barplot(x = df_clear['country'], y = df_clear['x3'])
# Out:
# <AxesSubplot: xlabel='country', ylabel='x3'>

# %%
df.head()
# Out:
#        city      country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 0     Delhi        India  4.90  22.04  4.28  1.84  3.67  1.78  0.48  0.19
# 1  Shanghai        China  5.59  40.51  5.59  1.12  4.19  3.96  0.52  0.32
# 2   Jakarta    Indonesia  2.54  22.25  3.50  2.02  3.18  2.19  0.59  0.27
# 3    Manila  Philippines  3.54  27.40  3.54  1.24  1.90  2.91  0.93  0.51
# 4     Seoul  South Korea  7.16  52.77  6.03  3.02  4.52  3.86  1.46  0.78
#
#    ...     x47      x48     x49      x50      x51       x52       x53  \
# 0  ...   36.26   223.87  133.38   596.16   325.82   2619.46   1068.90
# 1  ...  121.19  1080.07  564.30  2972.57  1532.23  17333.09   9174.88
# 2  ...   80.32   482.85  270.15  1117.69   584.37   2694.05   1269.44
# 3  ...   61.82   559.52  281.78  1754.40   684.81   3536.04   2596.44
# 4  ...  108.30   809.83  583.60  2621.05  1683.74  21847.94  10832.90
#
#        x54   x55  data_quality
# 0   586.35  7.96             1
# 1  1382.83  5.01             1
# ...
